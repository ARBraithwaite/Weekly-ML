# %% [markdown]
# # Pytesseract

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
# !pip install pytesseract
# !brew install tesseract

# %%
import pytesseract

# %%
img_array = plt.imread('scanned-invoice.jpg')
img = Image.fromarray(img_array)

# %%
plt.imshow(img_array)

# %%
top_right = img_array[0:100, 820:]
plt.imshow(top_right)

# %%
ans = pytesseract.image_to_string(top_right)

# %%
print(ans)
# Out:
# 1-996-84199
# Sep 01, 204
# 1334-8037-4
# lof?
